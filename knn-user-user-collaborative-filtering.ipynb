# %%
import numpy as np
import pandas as pd
from math import sqrt 
import warnings
warnings.filterwarnings('ignore')

# %%
movie_movielens = pd.read_csv('/movie-lens-100k/movies.csv')
movielens_temp=pd.read_csv('/movie-lens-100k/movies.csv')
rating = pd.read_csv('/movie-lens-100k/ratings.csv')
movie_tmdb=pd.read_csv('/tmdb-movie-metadata/tmdb_5000_movies.csv')

# %%
movie_movielens.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie_movielens.shape
# Out:
# (9125, 3)

# %%
rating.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
rating.shape
# Out:
# (100004, 4)

# %%
movie_tmdb.shape
# Out:
# (4803, 20)

# %%
movie_tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
movielens_temp['year']=movielens_temp.title.str.extract('(\d\d\d\d)',expand=False)
movie_movielens['year']=movie_movielens.title.str.extract('(\d\d\d\d)',expand=False)
movie_movielens.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
movielens_temp['title']=movielens_temp.title.str.replace('(\(\d\d\d\d\))','',regex=True)
movielens_temp['title']=movielens_temp['title'].apply(lambda x:x.strip())
movie_movielens['title']=movie_movielens.title.str.replace('(\(\d\d\d\d\))','',regex=True)
movie_movielens['title']=movie_movielens['title'].apply(lambda x:x.strip())
movie_movielens.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
movie_tmdb['original_title'] = movie_tmdb['original_title'].astype(str).str.lower().str.replace(' ', '')
movie_movielens['title'] = movie_movielens['title'].astype(str).str.lower().str.replace(' ', '')

# %%
len(movie_movielens['title'].unique())
# Out:
# 8889

# %%
len(movie_tmdb['original_title'].unique())
# Out:
# 4801

# %%
duplicate_values = movie_tmdb.duplicated(subset='original_title', keep=False)

# Filter the DataFrame to keep only rows with unique values in the specified column
movie_tmdb = movie_tmdb[~duplicate_values]

# %%
movie_tmdb.shape
# Out:
# (4799, 20)

# %%
duplicate_values = movie_movielens.duplicated(subset='title', keep=False)

# Filter the DataFrame to keep only rows with unique values in the specified column
movie_movielens = movie_movielens[~duplicate_values]

# %%
movie_movielens.shape
# Out:
# (8675, 4)

# %%
movie=movie_movielens[movie_movielens['title'].isin(movie_tmdb['original_title'].tolist())]
movie.shape
# Out:
# (2455, 4)

# %%
movie=movielens_temp[movielens_temp['movieId'].isin(movie['movieId'].tolist())]
movie.shape
# Out:
# (2455, 4)

# %%
movie.head()
# Out:
#     movieId             title                                       genres  \
# 0         1         Toy Story  Adventure|Animation|Children|Comedy|Fantasy
# 9        10         GoldenEye                    Action|Adventure|Thriller
# 13       14             Nixon                                        Drama
# 14       15  Cutthroat Island                     Action|Adventure|Romance
# 15       16            Casino                                  Crime|Drama
#
#     year
# 0   1995
# 9   1995
# 13  1995
# 14  1995
# 15  1995

# %%
movie.shape
# Out:
# (2455, 4)

# %%
len(movie.index)
# Out:
# 2455

# %%
movie.drop(columns=['genres'],inplace=True)
movie.head()
# Out:
#     movieId             title  year
# 0         1         Toy Story  1995
# 9        10         GoldenEye  1995
# 13       14             Nixon  1995
# 14       15  Cutthroat Island  1995
# 15       16            Casino  1995

# %%
rating=rating[rating['movieId'].isin(movie['movieId'].tolist())]
rating.shape
# Out:
# (46710, 4)

# %%
rating.head()
# Out:
#     userId  movieId  rating   timestamp
# 2        1     1061     3.0  1260759182
# 3        1     1129     2.0  1260759185
# 7        1     1293     2.0  1260759148
# 10       1     1371     2.5  1260759135
# 11       1     1405     1.0  1260759203

# %%
rating.drop(columns=['timestamp'],inplace=True)

# %%
rating.head()
# Out:
#     userId  movieId  rating
# 2        1     1061     3.0
# 3        1     1129     2.0
# 7        1     1293     2.0
# 10       1     1371     2.5
# 11       1     1405     1.0

# %%
unique_user_ids=rating['userId'].unique()
len(unique_user_ids)
# Out:
# 671

# %%
from sklearn.model_selection import train_test_split
train_userIds,test_userIds=train_test_split(unique_user_ids,test_size=0.2, random_state=42)
len(train_userIds)
# Out:
# 536

# %%
len(test_userIds)
# Out:
# 135

# %%
rating.head()
# Out:
#     userId  movieId  rating
# 2        1     1061     3.0
# 3        1     1129     2.0
# 7        1     1293     2.0
# 10       1     1371     2.5
# 11       1     1405     1.0

# %%
train_rating = pd.DataFrame(columns=rating.columns)
test_rating = pd.DataFrame(columns=rating.columns)

for userId in train_userIds:
    train_rating=pd.concat([train_rating,rating[rating['userId']==userId]],ignore_index=True)

for userId in test_userIds:
    test_rating=pd.concat([test_rating,rating[rating['userId']==userId]],ignore_index=True)

# %%
train_rating
# Out:
#       userId movieId  rating
# 0        480       1     5.0
# 1        480      34     3.5
# 2        480     110     4.0
# 3        480     150     4.5
# 4        480     158     4.5
# ...      ...     ...     ...
# 35478    103    5816     4.0
# 35479    103    6502     4.0
# 35480    103    6874     5.0
# 35481    103    7438     5.0
# 35482    103    8636     3.5
#
# [35483 rows x 3 columns]

# %%
test_rating
# Out:
#       userId movieId  rating
# 0        362      70     3.5
# 1        362     235     3.0
# 2        362     296     4.5
# 3        362     356     4.0
# 4        362     541     4.5
# ...      ...     ...     ...
# 11222    236    5009     3.5
# 11223    236    5378     2.5
# 11224    236    5440     4.5
# 11225    236    5989     4.5
# 11226    236    6711     4.5
#
# [11227 rows x 3 columns]

# %%
#Create user profile from user ID (get it from data set)
import random
inputUserID = random.choice(test_userIds)
print(inputUserID)
inputUser = test_rating[test_rating['userId']==inputUserID]
inputUser.shape
# Out:
# 635
# (11, 3)

# %%
inputUser.head()
# Out:
#      userId movieId  rating
# 1997    635     111     3.5
# 1998    635     296     3.5
# 1999    635     527     2.0
# 2000    635    1089     4.0
# 2001    635    1193     4.0

# %%
movie.head()
# Out:
#     movieId             title  year
# 0         1         Toy Story  1995
# 9        10         GoldenEye  1995
# 13       14             Nixon  1995
# 14       15  Cutthroat Island  1995
# 15       16            Casino  1995

# %%
inputUserData = pd.merge(inputUser,movie)
inputUserData.head()
# Out:
#   userId movieId  rating                            title  year
# 0    635     111     3.5                      Taxi Driver  1976
# 1    635     296     3.5                     Pulp Fiction  1994
# 2    635     527     2.0                 Schindler's List  1993
# 3    635    1089     4.0                   Reservoir Dogs  1992
# 4    635    1193     4.0  One Flew Over the Cuckoo's Nest  1975

# %%
train_rating.head()
# Out:
#   userId movieId  rating
# 0    480       1     5.0
# 1    480      34     3.5
# 2    480     110     4.0
# 3    480     150     4.5
# 4    480     158     4.5

# %%
users=train_rating[train_rating['movieId'].isin(inputUserData['movieId'].tolist())]
users
# Out:
#       userId movieId  rating
# 8        480     296     4.0
# 33       480    1089     4.5
# 46       480    1485     4.5
# 75       480    2959     3.5
# 144      480    8874     5.0
# ...      ...     ...     ...
# 35384    271     296     4.5
# 35413    271    2329     4.0
# 35423    436     111     4.0
# 35461    103    2329     4.5
# 35466    103    2959     5.0
#
# [1172 rows x 3 columns]

# %%
users.shape
# Out:
# (1172, 3)

# %%
#this step is not required as train and test data are different
users=users.drop(users[users['userId']==inputUserID].index)
users.shape
# Out:
# (1172, 3)

# %%
userSubsetGroup=users.groupby(['userId'])

# %%
userSubsetGroup.head()
# Out:
#       userId movieId  rating
# 8        480     296     4.0
# 33       480    1089     4.5
# 46       480    1485     4.5
# 75       480    2959     3.5
# 144      480    8874     5.0
# ...      ...     ...     ...
# 35384    271     296     4.5
# 35413    271    2329     4.0
# 35423    436     111     4.0
# 35461    103    2329     4.5
# 35466    103    2959     5.0
#
# [1054 rows x 3 columns]

# %%
userSubsetGroup=sorted(userSubsetGroup,key=lambda x:len(x[1]),reverse=True)

# %%
userSubsetGroup[0:1]
# Out:
# [((15,),
#         userId movieId  rating
#   28262     15     111     5.0
#   28284     15     296     5.0
#   28300     15     527     4.0
#   28340     15    1089     4.0
#   28347     15    1193     5.0
#   28382     15    1485     3.0
#   28454     15    2329     1.0
#   28507     15    2959     5.0
#   28597     15    3994     4.0
#   28784     15    8874     2.5
#   29043     15  112552     1.5)]

# %%
inputUserData.head()
# Out:
#   userId movieId  rating                            title  year
# 0    635     111     3.5                      Taxi Driver  1976
# 1    635     296     3.5                     Pulp Fiction  1994
# 2    635     527     2.0                 Schindler's List  1993
# 3    635    1089     4.0                   Reservoir Dogs  1992
# 4    635    1193     4.0  One Flew Over the Cuckoo's Nest  1975

# %%
from scipy.spatial.distance import cosine


pearsonCorDic = {}
cosineSimilarityDic = {}

for name, group in userSubsetGroup:
    group=group.sort_values(by='movieId') #here they are already sorted
    inputUserData=inputUserData.sort_values(by='movieId') #here they are already in sorted order
    
    n=len(group)
    
    #Get the ratings for the movies that are common 
    temp=inputUserData[inputUserData['movieId'].isin(group['movieId'].tolist())]
    
    tempRatingList=temp['rating'].tolist()
    tempGroupList=group['rating'].tolist()
        
    x_mean=sum(tempRatingList)/float(n)
    y_mean=sum(tempGroupList)/float(n)
    
    Sxx= sqrt(sum(pow((i-x_mean),2) for i in tempRatingList))
    Syy= sqrt(sum(pow((i-y_mean),2) for i in tempGroupList))
    
    Sxy= sum((tempRatingList[i]-x_mean)*(tempGroupList[i]-y_mean) for i in range(0,n))
    
    #if denominator is not 0, then divide else 0 correlation
    
    if Sxx!=0 and Syy!=0:
        pearsonCorDic[name[0]]=Sxy/(Sxx*Syy)
    else:
        pearsonCorDic[name[0]]=0
        
    #Calculating cosine similarity
    vector_a = np.array(tempRatingList)
    vector_b = np.array(tempGroupList)
    
    norm_a = np.linalg.norm(vector_a)
    norm_b = np.linalg.norm(vector_b)
    
    vector_a_normalized = vector_a / norm_a
    vector_b_normalized = vector_b / norm_b
    
    cosine_similarity = np.dot(vector_a_normalized,vector_b_normalized)
    
    cosineSimilarityDic[name[0]]=cosine_similarity

# %%
pearsonCorDic.items()
# Out:
# dict_items([(15, 0.11150015294068492), (461, -4.028859127438572e-17), (547, -0.385659195478239), (17, 0.17820158745248058), (30, -0.2919120224759156), (468, 0.2846361599575971), (509, -0.2906591794880899), (23, 0.01665510463498261), (94, -0.47533295971786166), (243, 0.669374346314434), (262, 0.26709196421662046), (268, -0.578769403495685), (388, -0.21520264493646468), (450, 0.27307758888591627), (452, 0.01056383870062615), (544, -0.5050495243689606), (615, -0.3620330940191084), (664, 0.46291004988627577), (48, 0.23377812812322404), (88, 0.4216277813128003), (105, 0.5477225575051661), (125, -0.5103103630798287), (178, -0.48238191061886615), (345, 0.48304589153964805), (380, -0.19802950859533489), (423, -0.12499999999999997), (433, 0.01321406407718703), (472, 0.25617376914899), (519, 0.9233805168766386), (520, -0.5773502691896258), (564, 0.6842968850192395), (608, 0.22047927592204924), (654, -0.3459510000515284), (59, -0.4435776522811298), (138, -0.10846522890932808), (187, 0.7462025072446364), (199, -0.3860936712526722), (220, -0.4743416490252569), (232, 0.9707253433941511), (245, -0.25000000000000006), (253, 0.7661308776828738), (295, -0.7220285378321422), (297, 0.30151134457776363), (309, -0.405998971470575), (358, -0.12838814775327387), (431, 0.32635697593225266), (454, -0.4925182813112042), (463, -0.35931349533480844), (494, -0.43301270189221935), (522, 0.8323901147703647), (561, -0.17326508598327026), (563, 0.7416198487095665), (584, -0.6303868004187867), (587, -0.40757732270630875), (598, 0.1754116038614058), (627, 0.19482162504979922), (8, -0.3152441624956402), (26, 0.3962029078465306), (72, -0.3001225239993906), (97, 0.3375061807581558), (143, 0.9185586535436918), (150, -0.23312620206007845), (152, -0.7484551991837486), (195, -0.4564354645876384), (214, -0.38888888888888884), (240, -0.29484598755723435), (250, -0.4564354645876384), (267, -0.6666666666666666), (304, 0.9532062476387965), (378, 0.44444444444444425), (384, 0.8964214570007952), (428, 0), (430, -0.16666666666666666), (432, 0.9525793444156802), (442, 0), (475, 0.1336306209562122), (480, -0.11566298639324807), (501, 0.408248290463863), (505, -0.5819143739626463), (528, -0.16666666666666666), (562, 0.21004201260420155), (574, 0.0), (607, 0.6846531968814576), (647, -0.4082482904638631), (648, 0.2809757434745082), (665, -0.24397501823713327), (21, -0.9684959969581863), (22, -0.7071067811865475), (34, 0.0880450906325624), (84, -1.0), (118, -0.6666666666666666), (124, -0.5773502691896257), (130, 0.3429971702850177), (157, 0.7745966692414833), (160, 0.9710607611177228), (185, -0.19245008972987526), (201, 0.19245008972987526), (230, -0.30151134457776363), (231, -0.5773502691896258), (242, 0), (270, 0.5773502691896258), (292, 0.5773502691896257), (313, -0.8320502943378437), (352, -0.8944271909999159), (370, 0.3333333333333333), (371, 0.5773502691896258), (373, 0.6666666666666666), (379, -0.6666666666666666), (407, 0.3333333333333333), (412, -0.3823595564509362), (425, -0.0880450906325624), (434, -0.2357022603955158), (458, -0.6666666666666666), (510, 0.49892218025118684), (514, -0.5773502691896258), (527, 0.0), (560, -0.30151134457776363), (583, 0.0), (585, -0.440225453162812), (623, 0.457495710997814), (20, -1.0000000000000002), (27, -1.0000000000000002), (36, -1.0000000000000002), (38, 0.0), (62, 0.5000000000000001), (69, -0.27735009811261463), (95, -1.0), (99, -1.0000000000000002), (107, -0.5000000000000001), (147, 1.0000000000000002), (164, 1.0000000000000002), (168, -0.5000000000000001), (171, 0), (181, 0), (208, -0.5), (215, 0.6933752452815364), (219, 0.6933752452815364), (247, -0.5000000000000001), (273, 0), (274, 0), (281, -0.9707253433941511), (291, 1.0), (294, -1.0000000000000002), (299, 0.5000000000000001), (306, -0.5000000000000001), (334, 0.0), (342, -0.2773500981126145), (344, 0.6933752452815364), (348, 0.0), (350, 0), (359, -0.2773500981126146), (367, -0.2773500981126146), (385, 1.0000000000000002), (386, -0.5000000000000001), (387, 0.9707253433941508),  ...

# %%
cosineSimilarityDic.items()
# Out:
# dict_items([(15, 0.9227011102612477), (461, 0.9584502218257018), (547, 0.9410807009140532), (17, 0.9823009926658164), (30, 0.9547147403764173), (468, 0.9661065690291286), (509, 0.9471908268072774), (23, 0.9676105312711196), (94, 0.9321036446131276), (243, 0.9838396284495621), (262, 0.9775315689601098), (268, 0.9161130222207795), (388, 0.9453057045804331), (450, 0.9838259270345976), (452, 0.9432995220134445), (544, 0.9703664281556812), (615, 0.9639768546525715), (664, 0.9916827122899807), (48, 0.970110678939007), (88, 0.9439187247102888), (105, 0.9982103059607516), (125, 0.9650246134647417), (178, 0.9728869053710931), (345, 0.9860177325458912), (380, 0.9757455633855074), (423, 0.9910986702920488), (433, 0.9472943087097763), (472, 0.9448125950970058), (519, 0.9959991950703634), (520, 0.9706199339418922), (564, 0.9798747541127097), (608, 0.9816066318789634), (654, 0.9512007242566081), (59, 0.9535234906122403), (138, 0.9654710210907148), (187, 0.9910155233698451), (199, 0.9587485736899511), (220, 0.9500868849869024), (232, 0.9862217346229053), (245, 0.9076352477286183), (253, 0.9918371399051232), (295, 0.8978872704229619), (297, 0.9917565273940796), (309, 0.9702616941612223), (358, 0.9466382788624976), (431, 0.9616162761173925), (454, 0.975009539358732), (463, 0.9550560527716239), (494, 0.9684395438332865), (522, 0.989495043230521), (561, 0.9332417892437713), (563, 0.9921673745012765), (584, 0.951028176600355), (587, 0.9465448592413349), (598, 0.9595536028871375), (627, 0.9101840270360035), (8, 0.9532063841608774), (26, 0.9676868269078517), (72, 0.9711099954675527), (97, 0.9331804618472497), (143, 0.9914260068081623), (150, 0.9555695302053201), (152, 0.9778944939397303), (195, 0.9091372900969897), (214, 0.9632347153529346), (240, 0.9587988448976371), (250, 0.963104232665204), (267, 0.9944464389589831), (304, 0.9766145344124029), (378, 0.9811890494319073), (384, 0.989368217531245), (428, 0.9978157964455983), (430, 0.9960183830073368), (432, 0.9950456150874907), (442, 0.9632419486019034), (475, 0.9956244323845294), (480, 0.9699690413940276), (501, 0.9244849430274025), (505, 0.9581185207526685), (528, 0.9942633294482882), (562, 0.9747891839254911), (574, 0.9911455268335505), (607, 0.9854373031669961), (647, 0.9668928237852299), (648, 0.975477879516294), (665, 0.9500739116607436), (21, 0.888402312464543), (22, 0.9743629778771096), (34, 0.9688527042309185), (84, 0.9783497031189413), (118, 0.9518771749586078), (124, 0.9213475295997331), (130, 0.9226220933261875), (157, 0.9916159609060925), (160, 0.9946672537315288), (185, 0.9486550982586419), (201, 0.9737591410132116), (230, 0.992009890024218), (231, 0.9887535853608559), (242, 0.9743911956946198), (270, 0.9985120107170955), (292, 0.9730085108210398), (313, 0.8868791472623199), (352, 0.9781078072723743), (370, 0.9771111617387351), (371, 0.998463839851755), (373, 0.9849859462615158), (379, 0.963906956850374), (407, 0.9767087534357889), (412, 0.8741884564920108), (425, 0.9503138806464533), (434, 0.9502880232880084), (458, 0.9157303370786516), (510, 0.9460435581268558), (514, 0.9901783552186145), (527, 0.9868800746021713), (560, 0.9636497171826883), (583, 0.9898125048701336), (585, 0.9583063596641946), (623, 0.9760830388066271), (20, 0.6128364798273251), (27, 0.9428090415820634), (36, 0.9428090415820634), (38, 0.9693476163322097), (62, 0.9954728632785321), (69, 0.9429576233418175), (95, 0.9614890453604711), (99, 0.9316142209946916), (107, 0.9665860377618121), (147, 0.9833476453530574), (164, 0.9999057537342988), (168, 0.9886183566695658), (171, 0.9979402655783316), (181, 0.9981149841863163), (208, 0.9945358423571875), (215, 0.9795959999578474), (219, 0.9795959999578474), (247, 0.9266914600593301), (273, 0.9988130559615214), (274, 0.997940265578332), (281, 0.9519026763534344), (291, 0.9994056463070786), (294, 0.9437333462702184), (299, 0.9882871850048919), (306, 0.9418896761351423), (334, 0.993429526225186), (342, 0.9284620517995599), (344, 0.9795959999578474), (348, 0.9777777777777776), (35 ...

# %%
pearsonDF=pd.DataFrame.from_dict(pearsonCorDic,orient='index')
pearsonDF.columns=['similarityIndexPC']
pearsonDF['userId']=pearsonDF.index
pearsonDF.index=range(0,len(pearsonDF))
pearsonDF.head()
# Out:
#    similarityIndexPC  userId
# 0       1.115002e-01      15
# 1      -4.028859e-17     461
# 2      -3.856592e-01     547
# 3       1.782016e-01      17
# 4      -2.919120e-01      30

# %%
cosineDF=pd.DataFrame.from_dict(cosineSimilarityDic,orient='index')
cosineDF.columns=['similarityIndexCS']
cosineDF['userId']=cosineDF.index
cosineDF.index=range(0,len(cosineDF))
cosineDF.head()
# Out:
#    similarityIndexCS  userId
# 0           0.922701      15
# 1           0.958450     461
# 2           0.941081     547
# 3           0.982301      17
# 4           0.954715      30

# %%
topUsersPC=pearsonDF.sort_values(by='similarityIndexPC',ascending=False)[0:50]
topUsersPC.head(10)
# Out:
#      similarityIndexPC  userId
# 187                1.0      85
# 129                1.0     147
# 130                1.0     164
# 152                1.0     385
# 169                1.0     577
# 157                1.0     439
# 207                1.0     184
# 272                1.0     666
# 198                1.0     144
# 270                1.0     649

# %%
topUsersCS=cosineDF.sort_values(by='similarityIndexCS',ascending=False)[0:50]
topUsersCS.head(10)
# Out:
#      similarityIndexCS  userId
# 239                1.0     447
# 397                1.0     670
# 325                1.0     287
# 333                1.0     326
# 332                1.0     323
# 331                1.0     321
# 330                1.0     317
# 329                1.0     316
# 328                1.0     314
# 327                1.0     305

# %%
rating.head()
# Out:
#     userId  movieId  rating
# 2        1     1061     3.0
# 3        1     1129     2.0
# 7        1     1293     2.0
# 10       1     1371     2.5
# 11       1     1405     1.0

# %%
topUsersRatingPC=topUsersPC.merge(rating,left_on='userId',right_on='userId',how='inner')
topUsersRatingPC.head(300)
# Out:
#      similarityIndexPC  userId  movieId  rating
# 0                  1.0      85       10     5.0
# 1                  1.0      85       19     3.0
# 2                  1.0      85       21     4.0
# 3                  1.0      85       23     3.0
# 4                  1.0      85       44     2.0
# ..                 ...     ...      ...     ...
# 295                1.0     439      327     3.0
# 296                1.0     439      480     3.0
# 297                1.0     439      527     3.0
# 298                1.0     439      541     3.0
# 299                1.0     439      588     3.0
#
# [300 rows x 4 columns]

# %%
topUsersRatingCS=topUsersCS.merge(rating,left_on='userId',right_on='userId',how='inner')
topUsersRatingCS.head()
# Out:
#    similarityIndexCS  userId  movieId  rating
# 0                1.0     447        1     3.0
# 1                1.0     447       10     3.0
# 2                1.0     447       17     3.0
# 3                1.0     447       19     3.0
# 4                1.0     447       21     3.0

# %%
topUsersRatingPC['weightedRating']=topUsersRatingPC['similarityIndexPC']*topUsersRatingPC['rating']
topUsersRatingPC.head()
# Out:
#    similarityIndexPC  userId  movieId  rating  weightedRating
# 0                1.0      85       10     5.0             5.0
# 1                1.0      85       19     3.0             3.0
# 2                1.0      85       21     4.0             4.0
# 3                1.0      85       23     3.0             3.0
# 4                1.0      85       44     2.0             2.0

# %%
topUsersRatingCS['weightedRating']=topUsersRatingCS['similarityIndexCS']*topUsersRatingCS['rating']
topUsersRatingCS.head()
# Out:
#    similarityIndexCS  userId  movieId  rating  weightedRating
# 0                1.0     447        1     3.0             3.0
# 1                1.0     447       10     3.0             3.0
# 2                1.0     447       17     3.0             3.0
# 3                1.0     447       19     3.0             3.0
# 4                1.0     447       21     3.0             3.0

# %%
tempTopUsersRatingPC=topUsersRatingPC.groupby('movieId').sum()[['similarityIndexPC','weightedRating']]
tempTopUsersRatingPC.columns=['sum_similarityIndex','sum_weightedRating']
tempTopUsersRatingPC.head()
# Out:
#          sum_similarityIndex  sum_weightedRating
# movieId
# 1                  20.659311           81.457190
# 10                 12.806099           48.862264
# 14                  0.953206            3.812825
# 15                  0.684297            0.684297
# 16                  8.574659           28.537296

# %%
tempTopUsersRatingCS=topUsersRatingCS.groupby('movieId').sum()[['similarityIndexCS','weightedRating']]
tempTopUsersRatingCS.columns=['sum_similarityIndex','sum_weightedRating']
tempTopUsersRatingCS.head()
# Out:
#          sum_similarityIndex  sum_weightedRating
# movieId
# 1                       19.0                75.5
# 10                       7.0                25.0
# 14                       2.0                 5.0
# 15                       2.0                 4.0
# 16                       4.0                16.5

# %%
recommendation_df_pc=tempTopUsersRatingPC
recommendation_df_pc['weighted average recommendation score']=recommendation_df_pc['sum_weightedRating']/recommendation_df_pc['sum_similarityIndex']
recommendation_df_pc.head()
# Out:
#          sum_similarityIndex  sum_weightedRating  \
# movieId
# 1                  20.659311           81.457190
# 10                 12.806099           48.862264
# 14                  0.953206            3.812825
# 15                  0.684297            0.684297
# 16                  8.574659           28.537296
#
#          weighted average recommendation score
# movieId
# 1                                     3.942880
# 10                                    3.815546
# 14                                    4.000000
# 15                                    1.000000
# 16                                    3.328097

# %%
recommendation_df_pc.shape
# Out:
# (1146, 3)

# %%
inputUserData.shape
# Out:
# (11, 5)

# %%
inputUserData.head()
# Out:
#   userId movieId  rating                            title  year
# 0    635     111     3.5                      Taxi Driver  1976
# 1    635     296     3.5                     Pulp Fiction  1994
# 2    635     527     2.0                 Schindler's List  1993
# 3    635    1089     4.0                   Reservoir Dogs  1992
# 4    635    1193     4.0  One Flew Over the Cuckoo's Nest  1975

# %%
recommendation_df_pc[recommendation_df_pc.index.isin(inputUserData['movieId'].tolist())].shape
# Out:
# (11, 3)

# %%
df_accuracy_pc=recommendation_df_pc[recommendation_df_pc.index.isin(inputUserData['movieId'].tolist())]
df_accuracy_pc.head()
# Out:
#          sum_similarityIndex  sum_weightedRating  \
# movieId
# 111                13.955184           61.948700
# 296                31.231512          139.696132
# 527                29.717108           93.539354
# 1089               11.125499           52.481165
# 1193               10.372479           50.541036
#
#          weighted average recommendation score
# movieId
# 111                                   4.439117
# 296                                   4.472922
# 527                                   3.147660
# 1089                                  4.717197
# 1193                                  4.872609

# %%
recommendation_df_cs=tempTopUsersRatingCS
recommendation_df_cs['weighted average recommendation score']=recommendation_df_cs['sum_weightedRating']/recommendation_df_cs['sum_similarityIndex']
recommendation_df_cs.head()
# Out:
#          sum_similarityIndex  sum_weightedRating  \
# movieId
# 1                       19.0                75.5
# 10                       7.0                25.0
# 14                       2.0                 5.0
# 15                       2.0                 4.0
# 16                       4.0                16.5
#
#          weighted average recommendation score
# movieId
# 1                                     3.973684
# 10                                    3.571429
# 14                                    2.500000
# 15                                    2.000000
# 16                                    4.125000

# %%
recommendation_df_cs.shape
# Out:
# (717, 3)

# %%
recommendation_df_pc.drop(columns=['sum_similarityIndex','sum_weightedRating'],inplace=True)
recommendation_df_pc.head()
# Out:
#          weighted average recommendation score
# movieId
# 1                                     3.942880
# 10                                    3.815546
# 14                                    4.000000
# 15                                    1.000000
# 16                                    3.328097

# %%
recommendation_df_cs.drop(columns=['sum_similarityIndex','sum_weightedRating'],inplace=True)
recommendation_df_cs.head()
# Out:
#          weighted average recommendation score
# movieId
# 1                                     3.973684
# 10                                    3.571429
# 14                                    2.500000
# 15                                    2.000000
# 16                                    4.125000

# %%
recommendation_df_cs.shape
# Out:
# (717, 1)

# %%
df_accuracy_cs=recommendation_df_cs[recommendation_df_cs.index.isin(inputUserData['movieId'].tolist())]
df_accuracy_cs.head()
# Out:
#          weighted average recommendation score
# movieId
# 111                                   4.000000
# 296                                   3.976190
# 527                                   4.636364
# 1193                                  3.750000
# 1485                                  3.500000

# %%
recommendation_df_pc.sort_values(by='weighted average recommendation score',ascending=False,inplace=True)
recommendation_df_pc.shape
# Out:
# (1146, 1)

# %%
recommendation_df_pc.tail()
# Out:
#          weighted average recommendation score
# movieId
# 80350                                      0.5
# 7448                                       0.5
# 1760                                       0.5
# 85510                                      0.5
# 89388                                      0.5

# %%
inputUserData.head()
# Out:
#   userId movieId  rating                            title  year
# 0    635     111     3.5                      Taxi Driver  1976
# 1    635     296     3.5                     Pulp Fiction  1994
# 2    635     527     2.0                 Schindler's List  1993
# 3    635    1089     4.0                   Reservoir Dogs  1992
# 4    635    1193     4.0  One Flew Over the Cuckoo's Nest  1975

# %%
recommendation_df_pc.head(100)
# Out:
#          weighted average recommendation score
# movieId
# 2361                                       5.0
# 4247                                       5.0
# 5617                                       5.0
# 5152                                       5.0
# 5015                                       5.0
# ...                                        ...
# 34332                                      4.5
# 33834                                      4.5
# 4223                                       4.5
# 2278                                       4.5
# 1942                                       4.5
#
# [100 rows x 1 columns]

# %%
rating_5_pc = (recommendation_df_pc['weighted average recommendation score']>=5).sum()
rating_5_pc
# Out:
# 65

# %%
recommendation_df_cs.sort_values(by='weighted average recommendation score',ascending=False,inplace=True)
recommendation_df_cs.head(10)
# Out:
#          weighted average recommendation score
# movieId
# 2948                                       5.0
# 1680                                       5.0
# 441                                        5.0
# 81229                                      5.0
# 102194                                     5.0
# 80906                                      5.0
# 3409                                       5.0
# 5218                                       5.0
# 1663                                       5.0
# 5108                                       5.0

# %%
rating_5_cs = (recommendation_df_cs['weighted average recommendation score']>=5).sum()
rating_5_cs
# Out:
# 84

# %%
recommendation_df_pc1=recommendation_df_pc.head(10)
recommendation_df_pc1
# Out:
#          weighted average recommendation score
# movieId
# 2361                                       5.0
# 4247                                       5.0
# 5617                                       5.0
# 5152                                       5.0
# 5015                                       5.0
# 1401                                       5.0
# 233                                        5.0
# 4566                                       5.0
# 42004                                      5.0
# 4232                                       5.0

# %%
recommendation_df_cs1=recommendation_df_cs.head(10)
recommendation_df_cs1
# Out:
#          weighted average recommendation score
# movieId
# 2948                                       5.0
# 1680                                       5.0
# 441                                        5.0
# 81229                                      5.0
# 102194                                     5.0
# 80906                                      5.0
# 3409                                       5.0
# 5218                                       5.0
# 1663                                       5.0
# 5108                                       5.0

# %%
recommendation_df_pc2=recommendation_df_pc1.merge(movie, left_on='movieId',right_on='movieId',how='inner')
print("Top 10 recommended movies with knn using pearson coefficient as distance metric:\n")
recommendation_df_pc2
# Out:
# Top 10 recommended movies with knn using pearson coefficient as distance metric:
#    movieId  weighted average recommendation score  \
# 0     2361                                    5.0
# 1     4247                                    5.0
# 2     5617                                    5.0
# 3     5152                                    5.0
# 4     5015                                    5.0
# 5     1401                                    5.0
# 6      233                                    5.0
# 7     4566                                    5.0
# 8    42004                                    5.0
# 9     4232                                    5.0
#
#                                  title  year
# 0                       Pink Flamingos  1972
# 1                             Joe Dirt  2001
# 2                            Secretary  2002
# 3                     We Were Soldiers  2002
# 4                       Monster's Ball  2001
# 5                Ghosts of Mississippi  1996
# 6                              Exotica  1994
# 7  American Ninja 2: The Confrontation  1987
# 8                         Transamerica  2005
# 9                             Spy Kids  2001

# %%
inputUserData.head()
# Out:
#   userId movieId  rating                            title  year
# 0    635     111     3.5                      Taxi Driver  1976
# 1    635     296     3.5                     Pulp Fiction  1994
# 2    635     527     2.0                 Schindler's List  1993
# 3    635    1089     4.0                   Reservoir Dogs  1992
# 4    635    1193     4.0  One Flew Over the Cuckoo's Nest  1975

# %%
df_accuracy_pc.head()
# Out:
#          sum_similarityIndex  sum_weightedRating  \
# movieId
# 111                13.955184           61.948700
# 296                31.231512          139.696132
# 527                29.717108           93.539354
# 1089               11.125499           52.481165
# 1193               10.372479           50.541036
#
#          weighted average recommendation score
# movieId
# 111                                   4.439117
# 296                                   4.472922
# 527                                   3.147660
# 1089                                  4.717197
# 1193                                  4.872609

# %%
df_accuracy_pc=df_accuracy_pc.sort_index()

# %%
df_accuracy_pc.head()
# Out:
#          sum_similarityIndex  sum_weightedRating  \
# movieId
# 111                13.955184           61.948700
# 296                31.231512          139.696132
# 527                29.717108           93.539354
# 1089               11.125499           52.481165
# 1193               10.372479           50.541036
#
#          weighted average recommendation score
# movieId
# 111                                   4.439117
# 296                                   4.472922
# 527                                   3.147660
# 1089                                  4.717197
# 1193                                  4.872609

# %%
inputUserData_accuracy_pc=inputUserData[inputUserData['movieId'].isin(df_accuracy_pc.index.tolist())]

# %%
inputUserData_accuracy_pc=inputUserData_accuracy_pc.sort_values(by='movieId')

# %%
inputUserData_accuracy_pc.head()
# Out:
#   userId movieId  rating                            title  year
# 0    635     111     3.5                      Taxi Driver  1976
# 1    635     296     3.5                     Pulp Fiction  1994
# 2    635     527     2.0                 Schindler's List  1993
# 3    635    1089     4.0                   Reservoir Dogs  1992
# 4    635    1193     4.0  One Flew Over the Cuckoo's Nest  1975

# %%
inputUserData_accuracy_pc.index
# Out:
# RangeIndex(start=0, stop=11, step=1)

# %%
inputUserData_accuracy_pc.index = range(len(inputUserData_accuracy_pc))

# %%
inputUserData_accuracy_pc.head()
# Out:
#   userId movieId  rating                            title  year
# 0    635     111     3.5                      Taxi Driver  1976
# 1    635     296     3.5                     Pulp Fiction  1994
# 2    635     527     2.0                 Schindler's List  1993
# 3    635    1089     4.0                   Reservoir Dogs  1992
# 4    635    1193     4.0  One Flew Over the Cuckoo's Nest  1975

# %%
df_accuracy_pc.index
# Out:
# Index([111, 296, 527, 1089, 1193, 1485, 2329, 2959, 3994, 8874, 112552], dtype='int64', name='movieId')

# %%
df_accuracy_pc['movieId']=df_accuracy_pc.index
df_accuracy_pc.head()
# Out:
#          sum_similarityIndex  sum_weightedRating  \
# movieId
# 111                13.955184           61.948700
# 296                31.231512          139.696132
# 527                29.717108           93.539354
# 1089               11.125499           52.481165
# 1193               10.372479           50.541036
#
#          weighted average recommendation score  movieId
# movieId
# 111                                   4.439117      111
# 296                                   4.472922      296
# 527                                   3.147660      527
# 1089                                  4.717197     1089
# 1193                                  4.872609     1193

# %%
df_accuracy_pc.index=range(len(df_accuracy_pc))
df_accuracy_pc.head()
# Out:
#    sum_similarityIndex  sum_weightedRating  \
# 0            13.955184           61.948700
# 1            31.231512          139.696132
# 2            29.717108           93.539354
# 3            11.125499           52.481165
# 4            10.372479           50.541036
#
#    weighted average recommendation score  movieId
# 0                               4.439117      111
# 1                               4.472922      296
# 2                               3.147660      527
# 3                               4.717197     1089
# 4                               4.872609     1193

# %%
df_accuracy_pc.shape
# Out:
# (11, 4)

# %%
sum_sd=0
sum_ad=0
for i in range(df_accuracy_pc.shape[0]):
    if(inputUserData_accuracy_pc.iloc[i]['movieId']==df_accuracy_pc.iloc[i]['movieId']):
        sum_sd+=(inputUserData_accuracy_pc.iloc[i]['rating']-df_accuracy_pc.iloc[i]['weighted average recommendation score'])**2
        sum_ad+=abs(inputUserData_accuracy_pc.iloc[i]['rating']-df_accuracy_pc.iloc[i]['weighted average recommendation score'])

rmse=sqrt(sum_sd/df_accuracy_pc.shape[0])
print("rmse of movie recommendations with knn using pearson coefficient:", rmse)

mae=sum_ad/df_accuracy_pc.shape[0]
print("mae of movie recommendations with knn using pearson coefficient:", mae)
# Out:
# rmse of movie recommendations with knn using pearson coefficient: 0.8090315364251466
# mae of movie recommendations with knn using pearson coefficient: 0.7403652608177776

# %%
recommendation_df_cs2=recommendation_df_cs1.merge(movie, left_on='movieId',right_on='movieId',how='inner')
print("Top 10 recommended movies with knn using cosine similarity as distance metric:\n")
recommendation_df_cs2.head()
# Out:
# Top 10 recommended movies with knn using cosine similarity as distance metric:
#    movieId  weighted average recommendation score                  title  year
# 0     2948                                    5.0  From Russia with Love  1963
# 1     1680                                    5.0          Sliding Doors  1998
# 2      441                                    5.0     Dazed and Confused  1993
# 3    81229                                    5.0                    Red  2010
# 4   102194                                    5.0                    Mud  2012

# %%
df_accuracy_cs.head()
# Out:
#          weighted average recommendation score
# movieId
# 111                                   4.000000
# 296                                   3.976190
# 527                                   4.636364
# 1193                                  3.750000
# 1485                                  3.500000

# %%
df_accuracy_cs.index
# Out:
# Index([111, 296, 527, 1193, 1485, 2329, 2959, 3994, 8874, 112552], dtype='int64', name='movieId')

# %%
inputUserData_accuracy_cs=inputUserData[inputUserData['movieId'].isin(df_accuracy_cs.index.tolist())]
inputUserData_accuracy_cs.head()
# Out:
#   userId movieId  rating                            title  year
# 0    635     111     3.5                      Taxi Driver  1976
# 1    635     296     3.5                     Pulp Fiction  1994
# 2    635     527     2.0                 Schindler's List  1993
# 4    635    1193     4.0  One Flew Over the Cuckoo's Nest  1975
# 5    635    1485     2.0                        Liar Liar  1997

# %%
df_accuracy_cs['movieId']=df_accuracy_cs.index
df_accuracy_cs.head()
# Out:
#          weighted average recommendation score  movieId
# movieId
# 111                                   4.000000      111
# 296                                   3.976190      296
# 527                                   4.636364      527
# 1193                                  3.750000     1193
# 1485                                  3.500000     1485

# %%
df_accuracy_cs.index=range(len(df_accuracy_cs))
df_accuracy_cs.head()
# Out:
#    weighted average recommendation score  movieId
# 0                               4.000000      111
# 1                               3.976190      296
# 2                               4.636364      527
# 3                               3.750000     1193
# 4                               3.500000     1485

# %%
inputUserData_accuracy_cs.head()
# Out:
#   userId movieId  rating                            title  year
# 0    635     111     3.5                      Taxi Driver  1976
# 1    635     296     3.5                     Pulp Fiction  1994
# 2    635     527     2.0                 Schindler's List  1993
# 4    635    1193     4.0  One Flew Over the Cuckoo's Nest  1975
# 5    635    1485     2.0                        Liar Liar  1997

# %%
inputUserData_accuracy_cs=inputUserData_accuracy_cs.sort_values(by='movieId')
inputUserData_accuracy_cs.head()
# Out:
#   userId movieId  rating                            title  year
# 0    635     111     3.5                      Taxi Driver  1976
# 1    635     296     3.5                     Pulp Fiction  1994
# 2    635     527     2.0                 Schindler's List  1993
# 4    635    1193     4.0  One Flew Over the Cuckoo's Nest  1975
# 5    635    1485     2.0                        Liar Liar  1997

# %%
inputUserData_accuracy_cs.index=range(len(inputUserData_accuracy_cs))
inputUserData_accuracy_cs.head()
# Out:
#   userId movieId  rating                            title  year
# 0    635     111     3.5                      Taxi Driver  1976
# 1    635     296     3.5                     Pulp Fiction  1994
# 2    635     527     2.0                 Schindler's List  1993
# 3    635    1193     4.0  One Flew Over the Cuckoo's Nest  1975
# 4    635    1485     2.0                        Liar Liar  1997

# %%
df_accuracy_cs=df_accuracy_cs.sort_values(by='movieId')
df_accuracy_cs.head()
# Out:
#    weighted average recommendation score  movieId
# 0                               4.000000      111
# 1                               3.976190      296
# 2                               4.636364      527
# 3                               3.750000     1193
# 4                               3.500000     1485

# %%
sum_sd=0
sum_ad=0
for i in range(df_accuracy_cs.shape[0]):
    if(inputUserData_accuracy_cs.iloc[i]['movieId']==df_accuracy_cs.iloc[i]['movieId']):
        sum_sd+=(inputUserData_accuracy_cs.iloc[i]['rating']-df_accuracy_cs.iloc[i]['weighted average recommendation score'])**2
        sum_ad+=abs(inputUserData_accuracy_cs.iloc[i]['rating']-df_accuracy_cs.iloc[i]['weighted average recommendation score'])
        
rmse=sqrt(sum_sd/df_accuracy_cs.shape[0])
print("rmse of movie recommendations with knn using cosine similarity between users:", rmse)

mae=sum_ad/df_accuracy_cs.shape[0]
print("mae of movie recommendations with knn using cosine similarity between users:", mae)
# Out:
# rmse of movie recommendations with knn using cosine similarity between users: 1.1641379038909012
# mae of movie recommendations with knn using cosine similarity between users: 0.9112554112554113
